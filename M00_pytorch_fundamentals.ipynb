# %% [markdown]
# <a href="https://colab.research.google.com/github/FrostedParadigm14/PyTorch-learning/blob/main/M00_pytorch_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.__version__
# Out:
# '2.10.0+cpu'
